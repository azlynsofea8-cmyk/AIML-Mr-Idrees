# %%
import numpy as np

# %%
array1 = np.array([1,2,3])

# %%
mypkg.APP_NAME

# %%
import mypkg

# %%
mypkg.greet("idrees")

# %%
mypkg.mood(2)

# %%
mypkg.newfun.selam("idrees")

# %%
from mypkg.newfun import funthings as nf

# %%
nf.selam("idrees!!!")
# Out:
# 'Selmat idrees!!!!!!'

# %%
nf.welcome("Idrees!!!")
# Out:
# 'Selamat Datang: Idrees!!!!!! You are very welcome here!!!'

# %%
np.random.randint()
